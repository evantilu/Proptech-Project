# %% [markdown]
# ## Part I
# #### Inspecting datasets

# %%
import pandas as pd
import numpy as np

# %%
'''Set display option'''
pd.set_option('display.max_rows', 15)
pd.set_option('display.max_columns', 100)

# %%
irv_urb = pd.read_csv('data/irvine_ca_city_2.csv')
irv_sub = pd.read_csv('data/irvine_ca_suburb_2.csv')
san_diego_urb = pd.read_csv('data/san_diego_ca_city_2.csv')
san_diego_sub = pd.read_csv('data/san_diego_ca_suburb_2.csv')
san_fran_urb = pd.read_csv('data/san_francisco_ca_city_2.csv')
san_fran_sub = pd.read_csv('data/san_francisco_ca_suburb_2.csv')

# %%
irv_urb
# Out:
#      month_date_yyyymm  postal_code    zip_name  nielsen_hh_rank  \
# 0               202201        92618  irvine, ca             4109
# 1               202201        92620  irvine, ca             1262
# 2               202112        92618  irvine, ca             4109
# 3               202111        92602  irvine, ca             4786
# 4               202111        92612  irvine, ca             2307
# ..                 ...          ...         ...              ...
# 255             201708        92602  irvine, ca             4786
# 256             201708        92603  irvine, ca             5600
# 257             201708        92612  irvine, ca             2307
# 258             201708        92618  irvine, ca             4109
# 259             201708        92620  irvine, ca             1262
#
#      hotness_rank  hotness_rank_mm  hotness_rank_yy  hotness_score  \
# 0            1772           -606.0           5647.0      74.641195
# 1            1177           -879.0           2803.0      79.059348
# 2            1166             93.0           7128.0      78.240454
# 3            3534           1342.0           6541.0      61.266337
# 4            2849            312.0           5521.0      65.066498
# ..            ...              ...              ...            ...
# 255          4093              NaN              NaN      64.323612
# 256          5906              NaN              NaN      53.593253
# 257          3260              NaN              NaN      69.040214
# 258          3326              NaN              NaN      68.571847
# 259          2999              NaN              NaN      70.701453
#
#      supply_score  demand_score  median_days_on_market  \
# 0       95.077580     54.204810                   16.0
# 1       89.394880     68.723817                   30.0
# 2       95.304529     61.176380                   20.0
# 3       70.898011     51.634663                   38.5
# 4       70.066306     60.066690                   39.0
# ..            ...           ...                    ...
# 255     87.730982     40.916243                   36.0
# 256     67.119177     40.067328                   57.0
# 257     90.369205     47.711223                   32.5
# 258     90.844890     46.298803                   32.0
# 259     93.548977     47.853928                   27.5
#
#      median_days_on_market_mm  median_dom_mm_day  median_days_on_market_yy  \
# 0                   -0.200000               -4.0                 -0.666667
# 1                    0.052632                1.5                 -0.166667
# 2                   -0.148936               -3.5                 -0.619048
# 3                   -0.197917               -9.5                 -0.496732
# 4                    0.114286                4.0                 -0.195876
# ..                        ...                ...                       ...
# 255                       NaN                NaN                       NaN
# 256                       NaN                NaN                       NaN
# 257                       NaN                NaN                       NaN
# 258                       NaN                NaN                       NaN
# 259                       NaN                NaN                       NaN
#
#      median_dom_yy_day  median_dom_vs_us  ldp_unique_viewers_per_property_mm  \
# 0                -32.0             -45.0                            0.272085
# 1                 -6.0             -31.0                            0.051184
# 2                -32.5             -33.5                           -0.105122
# 3                -38.0              -8.0                           -0.148893
# 4                 -9.5              -7.5                            0.054562
# ..                 ...               ...                                 ...
# 255                NaN             -30.5                                 NaN
# 256                NaN              -9.5                                 NaN
# 257                NaN             -34.0                                 NaN
# 258                NaN             -34.5                                 NaN
# 259                NaN             -39.0                                 NaN
#
#      ldp_unique_viewers_per_property_yy  \
# 0                              2.159184
# 1                              0.810042
# 2                              2.856531
# 3                              1.659151
# 4                              2.557075
# ..                                  ...
# 255                                 NaN
# 256                                 NaN
# 257                                 NaN
# 258                                 NaN
# 259                                 NaN
#
#      ldp_unique_viewers_per_property_vs_us  median_listing_price  \
# 0                                   1.1166             1300975.0
# 1                                   1.4500             1475000.0
# 2                                   1.2792             1393900.0
# 3                                   1.1203             2300000.0
# 4                                   1.2897              987500.0
# ..                                     ...                   ...
# 255                                 0.8637             1618950.0
# 256                                 0.8500             2124500.0
# 257                                 0.9716              867000.0
# 258                                 0.9471              950000.0
# 259                                 0.9742             1024344.0
#
#      median_listing_price_mm  median_listing_price_yy  \
# 0                  -0.066665                 0.131283
# 1                   0.068841                 0.172496
# 2                   0.056735                 0.212087
# 3                   0.008772                 0.473136
# 4                   0.012821                 0.371528
# ..                       ...                      ...
# 255                      NaN                      NaN
# 256                      NaN                      NaN
# 257                      NaN                      NaN
# 258                      NaN                      NaN
# 259                      NaN                      NaN
#
#      median_listing_price_vs_us  quality_flag  id  zip_code
# 0                        3.4693             1   1     92618
# 1                        3.9333             0   2     92620
# 2                        3.7171             1   1     92618
# 3                        6.0614             1   5     92602
# 4                        2.6025             1   3     92612
# ..                          ...           ...  ..       ...
# 255                      5.8027             1   5     92602
# 256                      7.6147             0   6     92603
# 257                      3.1075             0   3     92612
# 258                      3.4050             0   1     92618
# 259                      3.6715             0   2     92620
#
# [260 rows x 26 columns]

# %% [markdown]
# ### Check empty fields for each col in every dataset

# %%
tmp_1 = irv_urb.isnull().any()
print('irv_urb fields with empty values')
print('-------------------------------')
print(tmp_1[tmp_1])
print()

tmp_2 = irv_sub.isnull().any()
print('-------------------------------')
print('irv_sub fields with empty values')
print(tmp_2[tmp_2])
print()

tmp = san_diego_urb.isnull().any()
print('-------------------------------')
print('san_diego_urb fields with empty values')
print(tmp[tmp])
print()

tmp = san_diego_sub.isnull().any()
print('-------------------------------')
print('san_diego_sub fields with empty values')
print(tmp[tmp])
print()

tmp = san_fran_urb.isnull().any()
print('-------------------------------')
print('san_fran_urb fields with empty values')
print(tmp[tmp])
print()

tmp = san_fran_sub.isnull().any()
print('-------------------------------')
print('san_fran_sub fields with empty values')
print(tmp[tmp])
print()
# Out:
# irv_urb fields with empty values
# -------------------------------
# hotness_rank_mm                       True
# hotness_rank_yy                       True
# median_days_on_market_mm              True
# median_dom_mm_day                     True
# median_days_on_market_yy              True
# median_dom_yy_day                     True
# ldp_unique_viewers_per_property_mm    True
# ldp_unique_viewers_per_property_yy    True
# median_listing_price_mm               True
# median_listing_price_yy               True
# dtype: bool
#
# -------------------------------
# irv_sub fields with empty values
# hotness_rank_mm                       True
# hotness_rank_yy                       True
# median_days_on_market_mm              True
# median_dom_mm_day                     True
# median_days_on_market_yy              True
# median_dom_yy_day                     True
# ldp_unique_viewers_per_property_mm    True
# ldp_unique_viewers_per_property_yy    True
# median_listing_price_mm               True
# median_listing_price_yy               True
# dtype: bool
#
# -------------------------------
# san_diego_urb fields with empty values
# hotness_rank_mm                       True
# hotness_rank_yy                       True
# median_days_on_market_mm              True
# median_dom_mm_day                     True
# median_days_on_market_yy              True
# median_dom_yy_day                     True
# ldp_unique_viewers_per_property_mm    True
# ldp_unique_viewers_per_property_yy    True
# median_listing_price_mm               True
# median_listing_price_yy               True
# dtype: bool
#
# -------------------------------
# san_diego_sub fields with empty values
# hotness_rank_mm                       True
# hotness_rank_yy                       True
# median_days_on_market_mm              True
# median_dom_mm_day                     True
# median_days_on_market_yy              True
# median_dom_yy_day                     True
# ldp_unique_viewers_per_property_mm    True
# ldp_unique_viewers_per_property_yy    True
# median_listing_price_mm               True
# median_listing_price_yy               True
# dtype: bool
#
# -------------------------------
# san_fran_urb fields with empty values
# hotness_rank_mm                       True
# hotness_rank_yy                       True
# median_days_on_market_mm              True
# median_dom_mm_day                     True
# median_days_on_market_yy              True
# median_dom_yy_day                     True
# ldp_unique_viewers_per_property_mm    True
# ldp_unique_viewers_per_property_yy    True
# median_listing_price_mm               True
# median_listing_price_yy               True
# dtype: bool
#
# -------------------------------
# san_fran_sub fields with empty values
# hotness_rank_mm                       True
# hotness_rank_yy                       True
# median_days_on_market_mm              True
# median_dom_mm_day                     True
# median_days_on_market_yy              True
# median_dom_yy_day                     True
# ldp_unique_viewers_per_property_mm    True
# ldp_unique_viewers_per_property_yy    True
# median_listing_price_mm               True
# median_listing_price_yy               True
# dtype: bool

# %% [markdown]
# From above, there's not much info so after manual inspection, I confirmed that all datasets have the
# same fields that have empty values. And none of the fields are the critical ones that must not be dropped.

# %%
'''drop incomplete (bc they are also not necessary) columns'''

to_drop = ['hotness_rank_mm', 'hotness_rank_yy', 'median_days_on_market_mm', 'median_dom_mm_day', 'median_days_on_market_yy',
    'median_dom_yy_day', 'ldp_unique_viewers_per_property_mm', 'ldp_unique_viewers_per_property_yy',
    'median_listing_price_mm', 'median_listing_price_yy']

irv_sub = irv_sub.drop(to_drop, axis=1)
irv_urb = irv_urb.drop(to_drop, axis=1)
san_diego_sub = san_diego_sub.drop(to_drop, axis=1)
san_diego_urb = san_diego_urb.drop(to_drop, axis=1)
san_fran_urb = san_fran_urb.drop(to_drop, axis=1)
san_fran_sub = san_fran_sub.drop(to_drop, axis=1)

# %% [markdown]
# ## Part II
# #### Incorporate population density

# %%
'''
concatenate original urban and suburban datasets
and rename zip code code col to zipcode
'''

irv = pd.concat([irv_urb, irv_sub])
irv = irv.rename({'zip_code': 'zipcode'}, axis=1)

san_diego = pd.concat([san_diego_urb, san_diego_sub])
san_diego = san_diego.rename({'zip_code': 'zipcode'}, axis=1)

san_fran = pd.concat([san_fran_urb, san_fran_sub])
san_fran = san_fran.rename({'zip_code': 'zipcode'}, axis=1)

san_fran.describe()
# Out:
#        month_date_yyyymm   postal_code  nielsen_hh_rank  hotness_rank  \
# count        2431.000000   2431.000000      2431.000000   2431.000000
# mean       201943.897573  94557.116413      2547.639243   2953.908680
# std           126.900625    408.076737      1925.859675   2786.313915
# min        201708.000000  94085.000000        14.000000      1.000000
# 25%        201811.000000  94116.000000      1017.000000    579.000000
# 50%        201911.000000  94602.000000      1901.000000   1990.000000
# 75%        202012.000000  95110.000000      4053.000000   4690.500000
# max        202201.000000  95136.000000      7926.000000  11078.000000
#
#        hotness_score  supply_score  demand_score  median_days_on_market  \
# count    2431.000000   2431.000000   2431.000000            2431.000000
# mean       70.509833     82.944875     58.074790              33.771082
# std        19.372599     14.880992     28.740588              14.528132
# min        12.143986     18.356080      0.908359               5.500000
# 25%        56.567730     76.276527     32.720746              23.500000
# 50%        73.904716     88.151037     62.073418              31.000000
# 75%        87.279257     93.927641     84.734410              41.000000
# max        98.733946     99.330448     99.293790             102.000000
#
#        median_dom_vs_us  ldp_unique_viewers_per_property_vs_us  \
# count       2431.000000                            2431.000000
# mean         -27.339161                               1.543934
# std           17.965108                               0.962488
# min          -84.500000                               0.149500
# 25%          -39.500000                               0.814250
# 50%          -29.000000                               1.301600
# 75%          -15.000000                               2.075650
# max           50.000000                               6.461100
#
#        median_listing_price  median_listing_price_vs_us  quality_flag  \
# count          2.431000e+03                 2431.000000   2431.000000
# mean           1.146701e+06                    3.546118      0.495681
# std            5.177294e+05                    1.663211      0.500084
# min            3.750000e+05                    1.306800      0.000000
# 25%            7.666964e+05                    2.327300      0.000000
# 50%            1.035286e+06                    3.210700      0.000000
# 75%            1.422250e+06                    4.419100      1.000000
# max            4.545000e+06                   15.155100      1.000000
#
#                 id       zipcode
# count  2431.000000   2431.000000
# mean     28.603455  94557.116413
# std      21.461572    408.076737
# min       1.000000  94085.000000
# 25%      11.000000  94116.000000
# 50%      22.000000  94602.000000
# 75%      53.000000  95110.000000
# max      68.000000  95136.000000

# %%
'''read in population density file'''
pop_dens = pd.read_csv('./data/population_density/2020_population_density_by_zipcode.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/evantilu/My Drive (tl3098@columbia.edu)/Spring 2022/6865 Proptech/SP22_proptech_project/data_processing.ipynb Cell 12' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/evantilu/My%20Drive%20%28tl3098%40columbia.edu%29/Spring%202022/6865%20Proptech/SP22_proptech_project/data_processing.ipynb#ch0000009?line=0'>1</a> '''read in population density file'''
# ----> <a href='vscode-notebook-cell:/Users/evantilu/My%20Drive%20%28tl3098%40columbia.edu%29/Spring%202022/6865%20Proptech/SP22_proptech_project/data_processing.ipynb#ch0000009?line=1'>2</a> pop_dens = pd.read_csv('./data/population_density/2020_population_density_by_zipcode.csv')
#
# File /opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/util/_decorators.py?line=304'>305</a> if len(args) > num_allow_args:
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/util/_decorators.py?line=305'>306</a>     warnings.warn(
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/util/_decorators.py?line=306'>307</a>         msg.format(arguments=arguments),
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/util/_decorators.py?line=307'>308</a>         FutureWarning,
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/util/_decorators.py?line=308'>309</a>         stacklevel=stacklevel,
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/util/_decorators.py?line=309'>310</a>     )
# --> <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/util/_decorators.py?line=310'>311</a> return func(*args, **kwargs)
#
# File /opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=664'>665</a> kwds_defaults = _refine_defaults_read(
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=665'>666</a>     dialect,
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=666'>667</a>     delimiter,
#    (...)
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=675'>676</a>     defaults={"delimiter": ","},
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=676'>677</a> )
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=677'>678</a> kwds.update(kwds_defaults)
# --> <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=679'>680</a> return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=571'>572</a> _validate_names(kwds.get("names", None))
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=573'>574</a> # Create the parser.
# --> <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=574'>575</a> parser = TextFileReader(filepath_or_buffer, **kwds)
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=576'>577</a> if chunksize or iterator:
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=577'>578</a>     return parser
#
# File /opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=929'>930</a>     self.options["has_index_names"] = kwds["has_index_names"]
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=931'>932</a> self.handles: IOHandles | None = None
# --> <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=932'>933</a> self._engine = self._make_engine(f, self.engine)
#
# File /opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1212'>1213</a>     mode = "rb"
#    <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1213'>1214</a> # error: No overload variant of "get_handle" matches argument types
#    <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1214'>1215</a> # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1215'>1216</a> # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1216'>1217</a> self.handles = get_handle(  # type: ignore[call-overload]
#    <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1217'>1218</a>     f,
#    <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1218'>1219</a>     mode,
#    <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1219'>1220</a>     encoding=self.options.get("encoding", None),
#    <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1220'>1221</a>     compression=self.options.get("compression", None),
#    <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1221'>1222</a>     memory_map=self.options.get("memory_map", False),
#    <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1222'>1223</a>     is_text=is_text,
#    <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1223'>1224</a>     errors=self.options.get("encoding_errors", "strict"),
#    <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1224'>1225</a>     storage_options=self.options.get("storage_options", None),
#    <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1225'>1226</a> )
#    <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1226'>1227</a> assert self.handles is not None
#    <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/parsers/readers.py?line=1227'>1228</a> f = self.handles.handle
#
# File /opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/common.py?line=783'>784</a> elif isinstance(handle, str):
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/common.py?line=784'>785</a>     # Check whether the filename is to be opened in binary mode.
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/common.py?line=785'>786</a>     # Binary mode does not support 'encoding' and 'newline'.
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/common.py?line=786'>787</a>     if ioargs.encoding and "b" not in ioargs.mode:
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/common.py?line=787'>788</a>         # Encoding
# --> <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/common.py?line=788'>789</a>         handle = open(
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/common.py?line=789'>790</a>             handle,
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/common.py?line=790'>791</a>             ioargs.mode,
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/common.py?line=791'>792</a>             encoding=ioargs.encoding,
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/common.py?line=792'>793</a>             errors=errors,
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/common.py?line=793'>794</a>             newline="",
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/common.py?line=794'>795</a>         )
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/common.py?line=795'>796</a>     else:
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/common.py?line=796'>797</a>         # Binary mode
#     <a href='file:///opt/anaconda3/envs/4995_DS/lib/python3.9/site-packages/pandas/io/common.py?line=797'>798</a>         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/population_density/2020_population_density_by_zipcode.csv'

# %%
pop_dens
# Out:
#        ZCTA  population  area (sq mi)  pop_density
# 0     89010         469       404.233     1.160222
# 1     89019        2068       478.048     4.325925
# 2     89060       10692       462.549    23.115389
# 3     89061        5537        72.710    76.151836
# 4     89439        1244        14.579    85.328212
# ...     ...         ...           ...          ...
# 1764  96148         679         1.360   499.264706
# 1765  96150       30369       123.542   245.819236
# 1766  96155           0        37.043     0.000000
# 1767  96161       18782       181.839   103.289173
# 1768  97635         164        44.799     3.660796
#
# [1769 rows x 4 columns]

# %%
pop_dens.describe()
# Out:
#                ZCTA     population  area (sq mi)   pop_density
# count   1769.000000    1769.000000   1769.000000   1769.000000
# mean   93652.261164   22248.884681     60.232749   3419.037483
# std     1831.334177   22598.308562    112.614525   5582.005939
# min    89010.000000       0.000000      0.006000      0.000000
# 25%    92253.000000    1513.000000      5.047000     44.603593
# 50%    93654.000000   15974.000000     15.945000    721.362229
# 75%    95379.000000   36820.000000     69.079000   5116.342412
# max    97635.000000  110750.000000   1395.018000  56174.943567

# %%
# number of zip codes that have population = 0 (maybe PO Box)
(pop_dens['population'] == 0).sum()
# Out:
# 28

# %%
'''prepare the zip codes for all three cities'''
irv_zips = [
    92618, 92620, 92602, 92612, 92603, 92692, 
    92629, 92886, 92660, 92656, 92691, 92677, 
    92672, 92688, 92867]

san_diego_zips = [   
    92103, 92115, 92104, 92111, 92110, 92105,
    92120, 92122, 92102, 92106, 92126, 92107,
    92127, 92117, 92131, 92108, 92116, 92130,
    92101, 92118, 92129, 92119, 92113, 92154,
    92128, 92109, 92114, 92139, 92123,
    91911, 92040, 92019, 91935, 91945, 92075, 
    91910, 91913, 91977, 92021, 92037, 92064, 
    91950, 91914, 91915, 91942, 91932, 92067, 
    92014, 92118, 91902, 92071, 91941, 92020, 
    91901]

san_fran_zips = [
    94105, 94121, 94124, 94109, 94116, 94134, 
    94115, 94131, 94112, 94133, 94118, 94103, 
    94123, 94114, 94107, 94108, 94110, 94102, 
    94619, 94611, 94606, 94595, 94610, 94801, 
    94804, 94621, 94603, 94605, 94607, 94601, 
    94596, 95127, 95126, 95112, 95110, 94598, 
    94602, 95136, 94087, 94086, 95123, 95128, 
    95125, 95124, 94618, 95132, 94588, 94085, 
    95118, 95120, 95116, 95131, 95135]

# %%
# test an Irvine zip code
92618 in pop_dens.ZCTA.values
# Out:
# True

# %%
'''join market data with population density'''
irv_pop_dens = irv.set_index('zipcode').join(pop_dens.set_index('zipcode'))
san_diego_pop_dens = san_diego.set_index('zipcode').join(pop_dens.set_index('zipcode'))
san_fran_pop_dens = san_fran.set_index('zipcode').join(pop_dens.set_index('zipcode'))
# san_diego_pop_dens.describe()

# %% [markdown]
# #### Add a calculated column, population density
# NOTE: We can also use "grouping" in Tableau to achieve same result. Since these data are going to be fed to Tableau where most analysis/vizzes are performed, I will leave this field out of this pre-processed data and do the liftings there, in which case there's even more flexibility

# %%
'''definition of density level'''
high = 6500
mid = 3000

'''add density level column according to predefined threshold values'''

conditions = [
    (san_diego_pop_dens['pop_density'] >= high),
    ((san_diego_pop_dens['pop_density'] < high) & (san_diego_pop_dens['pop_density'] >= mid)),
    (san_diego_pop_dens['pop_density'] < mid)
]

values = ['high', 'mid', 'low']

'''comment out to perform the task'''
# san_diego_pop_dens['density_lv'] = np.select(conditions, values)
# san_diego_pop_dens
# Out:
# 'comment out to perform the task'

# %% [markdown]
# #### Export

# %%
'''export to csv'''
irv.to_csv('./data/clean_data/irvine.csv')
san_diego_pop_dens.to_csv('./data/clean_data/san_diego.csv')
san_fran_pop_dens.to_csv('./data/clean_data/san_francisco.csv')

# %%
tmp = pd.read_csv('./data/clean_data/san_diego.csv')
tmp
# Out:
#       zipcode  month_date_yyyymm  postal_code       zip_name  nielsen_hh_rank  \
# 0       91901             202008        91901     alpine, ca             6796
# 1       91901             202009        91901     alpine, ca             6796
# 2       91901             202010        91901     alpine, ca             6796
# 3       91901             202011        91901     alpine, ca             6796
# 4       91901             202012        91901     alpine, ca             6796
# ...       ...                ...          ...            ...              ...
# 2724    92154             201806        92154  san diego, ca              409
# 2725    92154             201807        92154  san diego, ca              409
# 2726    92154             201808        92154  san diego, ca              409
# 2727    92154             201809        92154  san diego, ca              409
# 2728    92154             201810        92154  san diego, ca              409
#
#       hotness_rank  hotness_score  supply_score  demand_score  \
# 0             1946      72.998360     84.449083     61.547637
# 1             2741      68.254717     87.007547     49.501887
# 2             1986      72.679869     90.956666     54.403072
# 3             3240      65.177822     75.665878     54.689766
# 4              688      84.225266     92.841524     75.609008
# ...            ...            ...           ...           ...
# 2724           432      89.737697     91.674875     87.800518
# 2725           489      88.357718     96.009510     80.705925
# 2726           424      88.628567     96.763010     80.494125
# 2727           697      85.072917     95.555879     74.589955
# 2728           704      84.625351     94.262564     74.988138
#
#       median_days_on_market  median_dom_vs_us  \
# 0                      29.0             -24.0
# 1                      25.0             -26.0
# 2                      21.0             -30.0
# 3                      39.5             -17.0
# 4                      28.0             -36.0
# ...                     ...               ...
# 2724                   24.0             -33.0
# 2725                   20.5             -39.0
# 2726                   20.0             -42.0
# 2727                   25.0             -40.0
# 2728                   29.5             -39.0
#
#       ldp_unique_viewers_per_property_vs_us  median_listing_price  \
# 0                                    1.3241              875000.0
# 1                                    1.0757              774000.0
# 2                                    1.1660              819000.0
# 3                                    1.1819              812000.0
# 4                                    1.6970              822000.0
# ...                                     ...                   ...
# 2724                                 2.2351              499000.0
# 2725                                 1.8225              520000.0
# 2726                                 1.8087              523775.0
# 2727                                 1.5869              500000.0
# 2728                                 1.6202              489500.0
#
#       median_listing_price_vs_us  quality_flag  id  population  area (sq mi)  \
# 0                         2.5000             0   1       17403        89.357
# 1                         2.2114             0   1       17403        89.357
# 2                         2.3400             1   1       17403        89.357
# 3                         2.3250             0   1       17403        89.357
# 4                         2.4105             0   1       17403        89.357
# ...                          ...           ...  ..         ...           ...
# 2724                      1.6633             1  30       79708        37.169
# 2725                      1.7339             0  30       79708        37.169
# 2726                      1.7503             1  30       79708        37.169
# 2727                      1.6722             0  30       79708        37.169
# 2728                      1.6371             0  30       79708        37.169
#
#       pop_density
# 0      194.758105
# 1      194.758105
# 2      194.758105
# 3      194.758105
# 4      194.758105
# ...           ...
# 2724  2144.475235
# 2725  2144.475235
# 2726  2144.475235
# 2727  2144.475235
# 2728  2144.475235
#
# [2729 rows x 19 columns]
